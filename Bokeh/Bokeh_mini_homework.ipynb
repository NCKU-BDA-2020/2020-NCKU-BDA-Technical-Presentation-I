# %% [markdown]
# # BOKEH mini-homework

# %% [markdown]
# ## Question - Using the dataset "iris" in the bokeh to make a plot which have :
# <ul>
#     <li><pre>a different color for each species</pre></li>
#     <li><pre>Add additional information to be displayed in a popup whenever the user hovers over a specific glyph. (hint: hover tool)</pre></li>
#     <li><pre>Mute glyphs by clicking the label in the legend</pre></li>
#     <li><pre>labels of x and y axis</pre></li>
#     <li><pre>update naumber of sampling by server(default is all and limit is 50)</pre></li>
# </ul>
#
# <pre>
#
# the result should be like...</pre>
# ![s.jpg](attachment:s.jpg)

# %% [markdown]
# ### Hint  : Import all the packages you need
# <blockquote>
#     <p><font color="green"><b>import</b></font> random <font color="green"><b>as</b></font> rd</p>
#     <p><font color="green"><b>import</b></font> pandas <font color="green"><b>as</b></font> pd</p>
#     <p><font color="green"><b>from</b></font> bokeh.sampledata.iris <font color="green"><b>import</b></font> flowers</p>
#     <p><font color="green"><b>from</b></font> bokeh.plotting <font color="green"><b>import</b></font> output_notebook, show</p>
#     <p><font color="green"><b>from</b></font> bokeh.layouts <font color="green"><b>import</b></font> column, row</p>
#     <p><font color="green"><b>from</b></font> bokeh.models <font color="green"><b>import</b></font> HoverTool, ColumnDataSource, Select, TextInput</p>
#     <p>output_notebook()</p>
# </blockquote>
